# %%
import ccxt

print(ccxt.exchanges)
# Out:
# ['ace', 'alpaca', 'ascendex', 'bequant', 'bigone', 'binance', 'binancecoinm', 'binanceus', 'binanceusdm', 'bingx', 'bit2c', 'bitbank', 'bitbay', 'bitbns', 'bitcoincom', 'bitfinex', 'bitfinex2', 'bitflyer', 'bitforex', 'bitget', 'bithumb', 'bitmart', 'bitmex', 'bitopro', 'bitpanda', 'bitrue', 'bitso', 'bitstamp', 'bittrex', 'bitvavo', 'bl3p', 'blockchaincom', 'btcalpha', 'btcbox', 'btcmarkets', 'btcturk', 'bybit', 'cex', 'coinbase', 'coinbaseprime', 'coinbasepro', 'coincheck', 'coinex', 'coinlist', 'coinmate', 'coinone', 'coinsph', 'coinspot', 'cryptocom', 'currencycom', 'delta', 'deribit', 'digifinex', 'exmo', 'fmfwio', 'gate', 'gateio', 'gemini', 'hitbtc', 'hitbtc3', 'hollaex', 'htx', 'huobi', 'huobijp', 'idex', 'independentreserve', 'indodax', 'kraken', 'krakenfutures', 'kucoin', 'kucoinfutures', 'kuna', 'latoken', 'lbank', 'luno', 'lykke', 'mercado', 'mexc', 'ndax', 'novadax', 'oceanex', 'okcoin', 'okx', 'p2b', 'paymium', 'phemex', 'poloniex', 'poloniexfutures', 'probit', 'timex',
# ...

# %%
import ccxt

exchange = ccxt.binanceus()
exchange.load_markets()
symbol = 'BTC/USDT'
amount = 1.2345678  # amount in base currency BTC
price = 87654.321  # price in quote currency USDT
formatted_amount = exchange.amount_to_precision(symbol, amount)
formatted_price = exchange.price_to_precision(symbol, price)
print(formatted_amount, formatted_price)
# Out:
# 1.23456 87654.32

# %%
import ccxt

exchange = ccxt.binanceus()
symbol = 'BTC/USDT'  # Example symbol
ticker = exchange.fetch_ticker(symbol)
price = ticker['last']  # Get the last traded price
volume24h = ticker.baseVolume # this gives last 24 h volume for binance only
print(f"The price of {symbol} is {price}")
print(f"The volume of {symbol} is {volume24h}")

# %%
import ccxt

exchange = ccxt.bitfinex()
symbol = 'BTC/USDT'  # Example symbol
ticker = exchange.fetch_ticker(symbol)
price = ticker['last']  # Get the last traded price
volume24h = ticker.baseVolume
print(f"The price of {symbol} is {price}")
print(f"The volume of {symbol} is {volume24h}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 7
#       5 ticker = exchange.fetch_ticker(symbol)
#       6 price = ticker['last']  # Get the last traded price
# ----> 7 volume24h = ticker.baseVolume
#       8 print(f"The price of {symbol} is {price}")
#       9 print(f"The volume of {symbol} is {volume24h}")
#
# AttributeError: 'dict' object has no attribute 'baseVolume'

# %%
import requests

url = "https://api-pub.bitfinex.com/v2/tickers?symbols=ALL"

headers = {"accept": "application/json"}

response = requests.get(url, headers=headers)

data = response.json()

btc_price = data[0][1]



print(response.text)
# Out:
# [["tBTCUSD",68224,2.82955496,68225,2.04472984,84,0.00123274,68225,1826.77195127,68534,67719],["tLTCUSD",89.961,3521.99985072,90.009,1092.64280878,1.841,0.02086592,90.071,6821.75109173,90.673,86.727],["tLTCBTC",0.001318,865.45540227,0.0013183,1519.26832026,0.0000307,0.02383355,0.0013188,416.09811567,0.0013322,0.0012753],["tETHUSD",3896.3,41.63653681,3896.4,94.24691783,4.9,0.00125915,3896.4,3492.88281386,3935.3,3865.6],["tETHBTC",0.05709,108.19011806,0.057091,197.37678964,-0.000077,-0.00134693,0.05709,793.41442362,0.057607,0.0569],["tETCBTC",0.00054762,5353.40764304,0.00054855,8456.87614432,-0.00001055,-0.01889022,0.00054794,471.37234528,0.00058,0.00054244],["tETCUSD",37.367,14307.63855651,37.414,11340.40534012,-0.735,-0.01928122,37.385,4015.97516973,39.48,36.974],["tRRTUSD",0.85,488957.19992371,0.89999,259122.46034462,0,0,0.85,20.1,0.85,0.85],["tZECUSD",34.026,1103.37552357,34.029,772.69265939,-0.507,-0.01464725,34.107,1268.79432805,35.5,33.8],["tZECBTC",0.00049793,537.69770818,0.0004
# ...

# %%
import requests
from datetime import datetime

# Bitfinex API
# docs (w key info): https://docs.bitfinex.com/reference/rest-public-ticker
keys = ['BID', 'BID_SIZE', 'ASK', 'ASK_SIZE', 'DAILY_CHANGE', 'DAILY_CHANGE_RELATIVE', 'LAST_PRICE', 'VOLUME', 'HIGH', 'LOW']
url = "https://api-pub.bitfinex.com/v2/ticker/tBTCUSD"

headers = {"accept": "application/json"}

response = requests.get(url, headers=headers)
btc_data = response.json()

print(response.text)

price = btc_data[keys.index('LAST_PRICE')]
volume = btc_data[keys.index('VOLUME')]
date_time = datetime.now()  # Assuming the current datetime for logging; adjust as necessary

symbol = 'BTC'
print(f"The price of {symbol} is {price}")
print(f"The volume of {symbol} is {volume}")
# Out:
# [68272,4.5392473,68277,2.73374012,1013,0.01506118,68272,4518.46900467,69839,66036]
# The price of BTC is 68272
# The volume of BTC is 4518.46900467

# %%
import requests

url = "https://api-pub.bitfinex.com/v2/candles/trade%3A1m%3AtBTCUSD/hist"

headers = {"accept": "application/json"}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# [[1710033120000,68754,68754,68754,68754,0.34034217999999994],[1710033060000,68702,68754,68754,68701,1.09081915],[1710033000000,68674,68702,68702,68665,0.61491876],[1710032940000,68654,68661,68662,68646,0.66054135],[1710032880000,68545,68643,68724,68545,6.71298011],[1710032820000,68518,68536,68599,68518,1.45580257],[1710032760000,68477,68513,68531,68447,2.52296577],[1710032700000,68500,68467,68500,68444,0.55706881],[1710032640000,68401,68498,68498,68401,1.51769943],[1710032580000,68436,68399,68436,68390,0.78539189],[1710032520000,68489,68432,68508,68412,2.83891091],[1710032460000,68223,68488,68488,68223,12.44271625],[1710032400000,68225,68223,68236,68223,0.69147454],[1710032340000,68227,68224,68229,68216,0.69891161],[1710032280000,68257,68218,68258,68218,1.5490858],[1710032220000,68256,68260,68263,68245,1.28424542],[1710032160000,68262,68250,68272,68250,0.43658919],[1710032100000,68235,68247,68266,68219,1.07972815],[1710032040000,68217,68229,68229,68214,0.70324422],[1710031980000,6822
# ...

# %%
import requests
from ratelimit import limits, sleep_and_retry

@sleep_and_retry
@limits(calls=90, period=10)
def api_call(i):
    url = "https://api-pub.bitfinex.com/v2/candles/trade%3A1m%3AtBTCUSD/hist"

    headers = {"accept": "application/json"}

    # response = requests.get(url, headers=headers)

    # print(response.text)
    print(f'Simulated API call: {i}')

for i in range(500):
    api_call(i)
# Out:
# Simulated API call: 0
# Simulated API call: 1
# Simulated API call: 2
# Simulated API call: 3
# Simulated API call: 4
# Simulated API call: 5
# Simulated API call: 6
# Simulated API call: 7
# Simulated API call: 8
# Simulated API call: 9
# Simulated API call: 10
# Simulated API call: 11
# Simulated API call: 12
# Simulated API call: 13
# Simulated API call: 14
# Simulated API call: 15
# Simulated API call: 16
# Simulated API call: 17
# Simulated API call: 18
# Simulated API call: 19
# Simulated API call: 20
# Simulated API call: 21
# Simulated API call: 22
# Simulated API call: 23
# Simulated API call: 24
# Simulated API call: 25
# Simulated API call: 26
# Simulated API call: 27
# Simulated API call: 28
# Simulated API call: 29
# Simulated API call: 30
# Simulated API call: 31
# Simulated API call: 32
# Simulated API call: 33
# Simulated API call: 34
# Simulated API call: 35
# Simulated API call: 36
# Simulated API call: 37
# Simulated API call: 38
# Simulated API call: 39
# ...
